# %% [markdown]
# # Setup

# %%
import json
import requests
import copy
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    """A simple function for posting to a URL and returning the json response"""
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response.json())
        return {}
    return response.json()

# %% [markdown]
# ## ARAGORN

# %% [markdown]
# ARAGORN is a Translator ARA that responds to TRAPI queries.  Here is a simple example of such a query:

# %%
trapi_input={
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids": ["NCBIGene:6611"],
                    "categories": ["biolink:Gene"]
                },
                "n1": {
                    "categories": ["biolink:ChemicalSubstance"]
                }
            },
            "edges": {
                "e01": {
                    "subject": "n0",
                    "object": "n1"
                }
            }
        }
    }
}

# %% [markdown]
# This query looks for Chemical Substances that are all connected directly to a given Gene (NCBIGene:6611)

# %%
#ARAGORN Endpoint: This is the url to post TRAPI queries
aragorn_trapi_url = 'https://aragorn.renci.org/1.1/query'

# %% [markdown]
# Now, we will POST the TRAPI message to ARAGORN's TRAPI interface using the python requests package:

# %%
start = dt.now()
#Call ARAGORN:
result = requests.post(aragorn_trapi_url, json=trapi_input)
end = dt.now()

print( result.status_code )

if result.status_code == 200:
    aragorn_result = result.json()
    print(f"ARAGORN produced {len(aragorn_result['message']['results'])} results in {end-start}.")
# Out:
# 200
# ARAGORN produced 158 results in 0:00:28.079535.

# %% [markdown]
# ARAGORN performs a series of operations.
# 1. *Strider* makes distributed calls to KPs to respond to the posted TRAPI query
# 2. *Answer Coalescer* looks for commonalities in the answers provided by Strider
# 3. *Omnicorp* adds literature co-occurrence edges between any nodes in a result
# 4. *Answer Weighting* Calculates numerical edge weights based on the literature support
# 5. *Scoring* Combines the answer weights into a final score for each answer.
#
# Because ARAGORN has merged some answers, these results don't all look the same.  First, note that ARAGORN has updated the query graph:

# %%
printjson(aragorn_result['message']['query_graph'])
# Out:
# {
#     "nodes": {
#         "n0": {
#             "ids": [
#                 "NCBIGene:6611"
#             ],
#             "categories": [
#                 "biolink:Gene"
#             ],
#             "is_set": false,
#             "constraints": null
#         },
#         "n1": {
#             "ids": null,
#             "categories": [
#                 "biolink:ChemicalSubstance"
#             ],
#             "is_set": true,
#             "constraints": null
#         },
#         "extra_qn_0": {
#             "ids": null,
#             "categories": [
#                 "biolink:NamedThing",
#                 "biolink:BiologicalEntity",
#                 "biolink:MolecularEntity",
#                 "biolink:Gene",
#                 "biolink:GeneOrGeneProduct",
#                 "biolink:MacromolecularMachine",
#                 "biolink:GenomicEntity"
#             ],
#             "is_set": false,
#             "constraints": null
#         }
#     },
#     "edges": {
#         "e01": {
#             "subject": "n0",
#             "object": "n1",
#             "predicates": null,
#             "relation": null,
#             "constraints": null
#         },
#         "extra_qe_0": {
#             "subject": "extra_qn_0",
#             "object": "n1",
#             "predicates": null,
#             "relation": null,
#             "constraints": null
#         }
#     }
# }

# %% [markdown]
# A new query node, and a new query edge connecting that node to the previous node `n1` have been added.  Now look at each result, and see 1) How many result nodes come back, and how many nodes are bound to `n1` in each answer.

# %%
scores = []
answer_node_count = []
merged_count = []
method = []
extra = []
for res_i, result in enumerate(aragorn_result['message']['results']):
    scores.append(result['score'])
    answer_node_count.append(len(result['node_bindings']))
    merged_count.append(len(result['node_bindings']['n1']))
    try:
        method.append(result['node_bindings']['n1'][0]['coalescence_method'])
    except:
        method.append('Original')
df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method, 'Score':scores})

# %%
with pd.option_context('display.max_rows', 100, 'display.max_columns', 10):
    display(df)
# Out:
#      N_Answer_Nodes  N_Merged_Nodes            Method     Score
# 0                 3               7  graph_enrichment  4.379434
# 1                 3               7  graph_enrichment  4.177219
# 2                 3               6  graph_enrichment  3.985845
# 3                 3               6  graph_enrichment  3.500000
# 4                 3               5  graph_enrichment  3.500000
# ..              ...             ...               ...       ...
# 153               3               2  graph_enrichment  0.000000
# 154               3               2  graph_enrichment  0.000000
# 155               3               8  graph_enrichment  0.000000
# 156               3               3  graph_enrichment  0.000000
# 157               3               2  graph_enrichment  0.000000
#
# [158 rows x 4 columns]

# %% [markdown]
# ### Uncoalesced answers

# %% [markdown]
# The above table shows three kinds of answers: The 'original' set of answers that have not undergone any coalescence.  These contain 2 nodes corresponding to the original 2 question nodes, and each answer consists of only a single knowledge graph node bound to the query graph node `n1`.  Each answer is completely independent.  These answers are simply the scored output of strider.  We can construct an answerset of only these answers like this:

# %%
simple_result = copy.deepcopy(aragorn_result)
simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings']['n1'][0], 
           aragorn_result['message']['results'])
)
print(len(simple_result['message']['results']))
# Out:
# 64

# %%
#Print the names of the answers
for result in simple_result['message']['results']:
    #Each answer has an identifier:
    n1_id = result['node_bindings']['n1'][0]['id']
    #The information for that identifier is in the KG:
    node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
    #Each node has a name
    print(node['name'])
# Out:
# Spermine
# indicator
# Spermine
# 5'-Deoxy-5'-methylthioadenosine
# Spermidine
# Spermine
# Spermine
# 5'-Deoxy-5'-methylthioadenosine
# Spermidine
# nucleobase
# Spermine
# 5'-Deoxy-5'-methylthioadenosine
# Spermidine
# Spermine
# Mexiletine
# Procysteine
# 5,7-Dihydroxy-2-(4-hydroxyphenyl)chroman-4-one
# Dactolisib
# Ricinine
# Dosulepin
# (3-Bromo-2,5-dimethoxy-7-bicyclo[4.2.0]octa-1(6),2,4-trienyl)methanamine
# Taxifolin
# Irinotecan
# (2S,3R,5R)-3,4-Dihydroxy-5-[6-[(3-iodophenyl)methylamino]-9-purinyl]-N-methyl-2-oxolanecarboxamide
# Mocetinostat
# Saclofen
# 4,7-Dichloro-3-hydroxy-3-[2-(4-methoxyphenyl)-2-oxoethyl]-1H-indol-2-one
# Parecoxib
# Troxipide
# N-[3-[[5-Chloro-2-[4-(4-methyl-1-piperazinyl)anilino]-4-pyrimidinyl]oxy]phenyl]-2-propenamide
# Tetradecylthioacetic acid
# (8Ar,9R)-5-[[(2R,4aR,6R,7R,8R)-7,8-dihydroxy-2-thiophen-2-yl-4,4a,6,7,8,8a-hexahydropyrano[3,2-d][1,3]dioxin-6-yl]oxy]-9-(4-hydroxy-3,5-dimethoxyphenyl)-5a,6,8a,9-tetrahydro-5H-isobenzofuro[6,5-f][1,3]benzodioxol-8-one
# Fenbufen
# N-[4-[1-(1,4-Dioxaspiro[4.5]dec-8-yl)-4-(8-oxa-3-azabicyclo[3.2.1]oct-3-yl)-1H-pyrazolo[3,4-d]pyrimidin-6-yl]phenyl]-N'-methylurea
# N-[4-(9-Acridinylmethyl)-3-methoxyphenyl]methanesulfonamide
# Ethyl (Z)-3-[5-(3-chlorophenyl)tetrazol-2-yl]prop-2-enoate
# Cytochalasin B
# CID 10219702
# 2-(3,4-Dimethoxyphenyl)-n-[2-(3,4-dimethoxyphenyl)ethyl]-n-methylethanamine
# 1-(2-(Diphenylmethoxy)ethyl)-4-(3-phenyl-2-propenyl)piperazine
# Diphenylcyclopropenone
# 9-(2,3-Dihydroxy-3-methylbutoxy)furo[3,2-g]chromen-7-one
# Etoposide
# Palbociclib
# Otenzepad
# Mesalamine
# Milnacipran
# Artemether
# 1-(2-Naphthalenyl)-2-propen-1-one
# Trimebutine
# (3R,5S)-7-[2-(4-Fluorophenyl)-5-isopropyl-3-phenyl-4-[(phenylamino)carbonyl]-1H-pyrrole-1-yl]-3,5-dihydroxyheptanoic acid
# Atorvastatin
# 1,4-Diaminobutane
# Spermidine
# Spermine
# (2R,3R,4S,5S)-2-(6-Aminopurin-9-yl)-5-(1,8-diaminooctan-3-ylsulfanylmethyl)oxolane-3,4-diol
# Adodatad
# S-Adenosylmethioninamine
# 1,3-Diaminopropane
# N1-Acetylspermine
# 1,4-Diaminobutane
# Bis(3-aminopropyl)amine
# CID 521353
# glucoglycerolipid

# %% [markdown]
# ### Graph Coalesced Answers

# %% [markdown]
# ARAGORN now examines this set of results, and tries to find commonalities between them.   In this case, there are two kinds of groupings found.  First we will look at cases where several of these entities are all connected to other nodes.  This is found via an enrichment calculation.  We want to know new nodes (the extra nodes of the modified query graph) that are connected to these n1 results more often than would happen by chance.

# %%
#The results that have been coalesced:
coalesced_results = list(
    filter( lambda x: 'coalescence_method'  in x['node_bindings']['n1'][0], 
           aragorn_result['message']['results'])
)

#Those that have been coalesced via a new node (graph coalescence)
graph_coalesced_results = list(
    filter( lambda x: x['node_bindings']['n1'][0]['coalescence_method'] == 'graph_enrichment', coalesced_results)
)
print(len(graph_coalesced_results))
# Out:
# 44

# %% [markdown]
# Each of these new results is a combination of results from the list of 37 results above.  For instance, the first coalesced result looks like this:

# %%
print_json(graph_coalesced_results[0])
# Out:
# {
#     "node_bindings": {
#         "n0": [
#             {
#                 "id": "NCBIGene:6611"
#             }
#         ],
#         "n1": [
#             {
#                 "id": "PUBCHEM.COMPOUND:60838",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:68911",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:36462",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4178",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5330286",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5573",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:119828",
#                 "p_value": 3.904388366202427e-11,
#                 "enriched_nodes": [
#                     "NCBIGene:1576"
#                 ],
#                 "coalescence_method": "graph_enrichment"
#             }
#         ],
#         "extra_qn_0": [
#             {
#                 "id": "NCBIGene:1576"
#             }
#         ]
#     },
#     "edge_bindings": {
#         "e01": [
#             {
#                 "id": "8a23065bea55",
#                 "weight": 1
#             },
#             {
#                 "id": "8f92dbb28ca1",
#                 "weight": 1
#             },
#             {
#                 "id": "8c92bddf620d",
#                 "weight": 1
#             },
#             {
#                 "id": "e1b17345df8b",
#                 "weight": 1
#             },
#             {
#                 "id": "8ee217e1b930",
#                 "weight": 1
#             },
#             {
#                 "id": "e6bc3a4d1c53",
#                 "weight": 1
#             },
#             {
#                 "id": "6dd4086c9e7a",
#                 "weight": 1
#             }
#         ],
#         "extra_qe_0": [
#             {
#                 "id": "-5881880183461909342",
#                 "weight": 1
#             },
#             {
#                 "id": "-5921695585510818707",
#                 "weight": 1
#             },
#             {
#                 "id": "-5616556878621100968",
#                 "weight": 1
#             },
#             {
#                 "id": "1281780697910080547",
#                 "weight": 1
#             },
#             {
#                 "id": "-5892917453158824508",
#                 "weight": 1
#             },
#             {
#                 "id": "8751420518281496661",
#                 "weight": 1
#             },
#             {
#                 "id": "6227845565501448563",
#                 "weight": 1
#             }
#         ],
#         "s26": [
#             {
#                 "id": "8a62dd00-9463-4201-b6a2-5335fe3fc82d",
#                 "weight": 0.8794342374535546
#             }
#         ]
#     },
#     "score": 4.379434237453553
# }

# %% [markdown]
# Note that while in the original query graph, `n1` was a normal node, in the modified query graph it has been made into a set.   For this answer, `n1` is now mapped to 7 of the compounds.  This is because all 7 of these compounds have an edge of the same type linking them to extra_qn_0 (NCBIGene:1576).  We can see this by looking at the associated KG edges:

# %%
kg = aragorn_result['message']['knowledge_graph']
def print_gc_result(gc_result):
    print('p_value:', gc_result['node_bindings']['n1'][0]['p_value'])
    for eb in gc_result['edge_bindings']['extra_qe_0']:
        kge = aragorn_result['message']['knowledge_graph']['edges'][eb['id']]
        subject_node = kge['subject']
        object_node = kge['object']
        pred = kge['predicate']
        print( f"{kg['nodes'][subject_node]['name']} -[{pred}]-> {kg['nodes'][object_node]['name']}")
print_gc_result(graph_coalesced_results[0])
# Out:
# p_value: 3.904388366202427e-11
# CYP3A4 -[biolink:increases_degradation_of]-> Palbociclib
# CYP3A4 -[biolink:increases_degradation_of]-> Mexiletine
# CYP3A4 -[biolink:increases_degradation_of]-> Trimebutine
# CYP3A4 -[biolink:increases_degradation_of]-> Parecoxib
# CYP3A4 -[biolink:increases_degradation_of]-> Irinotecan
# CYP3A4 -[biolink:increases_degradation_of]-> Etoposide
# CYP3A4 -[biolink:increases_degradation_of]-> Artemether

# %% [markdown]
# This set of original results have been linked together because they are all degraded by CYP3A4.  The p-value of this enrichment is 3.9e-11.  The other similarly coalesced nodes are shown here:

# %%
for i,result in enumerate(graph_coalesced_results):
    print('Result',i)
    print_gc_result(result)
# Out:
# Result 0
# p_value: 3.904388366202427e-11
# CYP3A4 -[biolink:increases_degradation_of]-> Palbociclib
# CYP3A4 -[biolink:increases_degradation_of]-> Mexiletine
# CYP3A4 -[biolink:increases_degradation_of]-> Trimebutine
# CYP3A4 -[biolink:increases_degradation_of]-> Parecoxib
# CYP3A4 -[biolink:increases_degradation_of]-> Irinotecan
# CYP3A4 -[biolink:increases_degradation_of]-> Etoposide
# CYP3A4 -[biolink:increases_degradation_of]-> Artemether
# Result 1
# p_value: 3.9436239074062695e-28
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> AMD1
# N1-Acetylspermine -[biolink:interacts_with]-> AMD1
# 1,3-Diaminopropane -[biolink:interacts_with]-> AMD1
# Spermine -[biolink:interacts_with]-> AMD1
# 1,4-Diaminobutane -[biolink:interacts_with]-> AMD1
# Spermidine -[biolink:interacts_with]-> AMD1
# S-Adenosylmethioninamine -[biolink:interacts_with]-> AMD1
# Result 2
# p_value: 2.0139774271674997e-24
# N1-Acetylspermine -[biolink:interacts_with]-> ODC1
# Spermidine -[biolink:interacts_with]-> ODC1
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> ODC1
# 1,4-Diaminobutane -[biolink:interacts_with]-> ODC1
# Spermine -[biolink:interacts_with]-> ODC1
# 1,3-Diaminopropane -[biolink:interacts_with]-> ODC1
# Result 3
# p_value: 2.0139774271674997e-24
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> MTAP
# Spermine -[biolink:interacts_with]-> MTAP
# Spermidine -[biolink:interacts_with]-> MTAP
# 5'-Deoxy-5'-methylthioadenosine -[biolink:interacts_with]-> MTAP
# N1-Acetylspermine -[biolink:interacts_with]-> MTAP
# 1,4-Diaminobutane -[biolink:interacts_with]-> MTAP
# Result 4
# p_value: 4.730149833257941e-21
# Spermine -[biolink:interacts_with]-> OAZ1
# Spermidine -[biolink:interacts_with]-> OAZ1
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> OAZ1
# 1,4-Diaminobutane -[biolink:interacts_with]-> OAZ1
# N1-Acetylspermine -[biolink:interacts_with]-> OAZ1
# Result 5
# p_value: 1.0223399135357285e-20
# 1,4-Diaminobutane -[biolink:interacts_with]-> SRM
# 5'-Deoxy-5'-methylthioadenosine -[biolink:interacts_with]-> SRM
# Spermine -[biolink:interacts_with]-> SRM
# S-Adenosylmethioninamine -[biolink:interacts_with]-> SRM
# Spermidine -[biolink:interacts_with]-> SRM
# Result 6
# p_value: 2.0033567084199524e-07
# Etoposide -[biolink:contributes_to]-> diarrheal disease
# Irinotecan -[biolink:contributes_to]-> diarrheal disease
# Palbociclib -[biolink:contributes_to]-> diarrheal disease
# Mesalamine -[biolink:contributes_to]-> diarrheal disease
# Result 7
# p_value: 7.033262225845803e-07
# Palbociclib -[biolink:contributes_to]-> Vomiting
# Mesalamine -[biolink:contributes_to]-> Vomiting
# Etoposide -[biolink:contributes_to]-> Vomiting
# Irinotecan -[biolink:contributes_to]-> Vomiting
# Result 8
# p_value: 1.901000350246138e-21
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> PMF1
# Spermine -[biolink:interacts_with]-> PMF1
# N1-Acetylspermine -[biolink:interacts_with]-> PMF1
# Spermidine -[biolink:interacts_with]-> PMF1
# 1,4-Diaminobutane -[biolink:interacts_with]-> PMF1
# Result 9
# p_value: 4.730149833257941e-21
# N1-Acetylspermine -[biolink:interacts_with]-> PDPR
# Spermidine -[biolink:interacts_with]-> PDPR
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> PDPR
# 1,4-Diaminobutane -[biolink:interacts_with]-> PDPR
# Spermine -[biolink:interacts_with]-> PDPR
# Result 10
# p_value: 3.5916218505919564e-20
# N1-Acetylspermine -[biolink:interacts_with]-> CHDH
# 1,4-Diaminobutane -[biolink:interacts_with]-> CHDH
# Spermine -[biolink:interacts_with]-> CHDH
# Spermidine -[biolink:interacts_with]-> CHDH
# Bis(3-aminopropyl)amine -[biolink:interacts_with]-> CHDH
# Result 11
# p_value: 1.240903469462318e-07
# Etoposide -[biolink:prevents]-> hearing loss disorder
# Mesalamine -[biolink:prevents]-> hearing loss disorder
# Irinotecan -[biolink:prevents]-> hearing loss disorder
# Result 12
# p_value: 6.307683812206184e-07
# Palbociclib -[biolink:treats]-> acute myeloid leukemia
# Irinotecan -[biolink:treats]-> acute myeloid leukemia
# Etoposide -[biolink:treats]-> acute myeloid leukemia
# Result 13
# p_value: 1.3109617450518593e-07
# Irinotecan -[biolink:causes_adverse_event]-> pneumocystosis
# Etoposide -[biolink:causes_adverse_event]-> pneumocystosis
# Mesalamine -[biolink:causes_adverse_event]-> pneumocystosis
# Result 14
# p_value: 8.312446100680554e-07
# Irinotecan -[biolink:prevents]-> osteomyelitis (disease)
# Mesalamine -[biolink:prevents]-> osteomyelitis (disease)
# Etoposide -[biolink:prevents]-> osteomyelitis (disease)
# Result 15
# p_value: 4.0216367022425543e-07
# Etoposide -[biolink:treats]-> colorectal neoplasm
# Mesalamine -[biolink:treats]-> colorectal neoplasm
# Irinotecan -[biolink:treats]-> colorectal neoplasm
# Result 16
# p_value: 7.290516391444708e-13
# Spermidine -[biolink:interacts_with]-> SRM
# Spermine -[biolink:interacts_with]-> SRM
# 1,4-Diaminobutane -[biolink:interacts_with]-> SRM
# Result 17
# p_value: 6.512532135084513e-07
# Etoposide -[biolink:prevents]-> dopa-responsive dystonia
# Mesalamine -[biolink:prevents]-> dopa-responsive dystonia
# Irinotecan -[biolink:prevents]-> dopa-responsive dystonia
# Result 18
# p_value: 2.8395452584691076e-08
# Irinotecan -[biolink:causes_adverse_event]-> lung abscess (disease)
# Etoposide -[biolink:causes_adverse_event]-> lung abscess (disease)
# Mesalamine -[biolink:causes_adverse_event]-> lung abscess (disease)
# Result 19
# p_value: 4.4895507186915324e-07
# CYP2B6 -[biolink:increases_degradation_of]-> Artemether
# CYP2B6 -[biolink:increases_degradation_of]-> Irinotecan
# CYP2B6 -[biolink:increases_degradation_of]-> Mexiletine
# Result 20
# p_value: 3.87319092905419e-07
# ABCG2 -[biolink:increases_degradation_of]-> Irinotecan
# ABCG2 -[biolink:increases_degradation_of]-> Palbociclib
# ABCG2 -[biolink:increases_degradation_of]-> Etoposide
# Result 21
# p_value: 1.088244601552577e-12
# 1,4-Diaminobutane -[biolink:directly_interacts_with]-> KCNJ2
# Spermidine -[biolink:directly_interacts_with]-> KCNJ2
# Spermine -[biolink:directly_interacts_with]-> KCNJ2
# Result 22
# p_value: 2.596027839109558e-07
# Irinotecan -[biolink:contributes_to]-> dysthymic disorder
# Mesalamine -[biolink:contributes_to]-> dysthymic disorder
# Palbociclib -[biolink:contributes_to]-> dysthymic disorder
# Etoposide -[biolink:contributes_to]-> dysthymic disorder
# Result 23
# p_value: 2.1398315565017084e-09
# 5'-Deoxy-5'-methylthioadenosine -[biolink:interacts_with]-> SRM
# Spermine -[biolink:interacts_with]-> SRM
# Result 24
# p_value: 4.591192814954814e-13
# 1,4-Diaminobutane -[biolink:interacts_with]-> OAZ1
# Spermine -[biolink:interacts_with]-> OAZ1
# Spermidine -[biolink:interacts_with]-> OAZ1
# Result 25
# p_value: 9.047691992320636e-07
# Irinotecan -[biolink:increases_localization_of]-> FAS
# Etoposide -[biolink:increases_localization_of]-> FAS
# Result 26
# p_value: 5.090468292891404e-07
# RB1 -[biolink:affects_response_to]-> Palbociclib
# RB1 -[biolink:affects_response_to]-> Etoposide
# Result 27
# p_value: 6.9279160189106e-07
# TOP2A -[biolink:increases_response_to]-> Etoposide
# TOP2A -[biolink:increases_response_to]-> Irinotecan
# Result 28
# p_value: 6.9279160189106e-07
# UGT1A1 -[biolink:affects_response_to]-> Etoposide
# UGT1A1 -[biolink:affects_response_to]-> Irinotecan
# Result 29
# p_value: 6.2742898231296e-08
# Mesalamine -[biolink:causes_adverse_event]-> Crohn ileitis
# Etoposide -[biolink:causes_adverse_event]-> Crohn ileitis
# Irinotecan -[biolink:causes_adverse_event]-> Crohn ileitis
# Result 30
# p_value: 2.656986845074019e-13
# 1,4-Diaminobutane -[biolink:decreases_activity_of]-> None
# Spermidine -[biolink:decreases_activity_of]-> None
# Spermine -[biolink:decreases_activity_of]-> None
# Result 31
# p_value: 2.656986845074019e-13
# 1,4-Diaminobutane -[biolink:interacts_with]-> PMF1
# Spermine -[biolink:interacts_with]-> PMF1
# Spermidine -[biolink:interacts_with]-> PMF1
# Result 32
# p_value: 4.591192814954814e-13
# Spermidine -[biolink:interacts_with]-> PDPR
# Spermine -[biolink:interacts_with]-> PDPR
# 1,4-Diaminobutane -[biolink:interacts_with]-> PDPR
# Result 33
# p_value: 6.9279160189106e-07
# Irinotecan -[biolink:causes_adverse_event]-> Thrombosis of aorta
# Etoposide -[biolink:causes_adverse_event]-> Thrombosis of aorta
# Result 34
# p_value: 9.047691992320636e-07
# Etoposide -[biolink:causes_adverse_event]-> Bacillus infection
# Irinotecan -[biolink:causes_adverse_event]-> Bacillus infection
# Result 35
# p_value: 9.047691992320636e-07
# Irinotecan -[biolink:causes_adverse_event]-> Treatment refused due to parent's wishes
# Etoposide -[biolink:causes_adverse_event]-> Treatment refused due to parent's wishes
# Result 36
# p_value: 8.84331917719657e-10
# glucoglycerolipid -[biolink:directly_interacts_with]-> TUBB4B
# CID 521353 -[biolink:directly_interacts_with]-> TUBB4B
# Result 37
# p_value: 8.84331917719657e-10
# glucoglycerolipid -[biolink:directly_interacts_with]-> LGALS7B
# CID 521353 -[biolink:directly_interacts_with]-> LGALS7B
# Result 38
# p_value: 8.84331917719657e-10
# CID 521353 -[biolink:directly_interacts_with]-> RRBP1
# glucoglycerolipid -[biolink:directly_interacts_with]-> RRBP1
# Result 39
# p_value: 1.7468556887556165e-10
# Result 40
# p_value: 2.7948646195425653e-09
# 5'-Deoxy-5'-methylthioadenosine -[biolink:interacts_with]-> SMS
# Spermine -[biolink:interacts_with]-> SMS
# Result 41
# p_value: 1.586695648732096e-33
# Result 42
# p_value: 1.2397132968460726e-14
# Result 43
# p_value: 1.7468556887556165e-10

# %% [markdown]
# So we can see that at subset of the original results share treatment, adverse event, and metabolic profiles

# %% [markdown]
# ### Property Coalesced Answers

# %% [markdown]
# The other form of enrichment shown looks for clusters of nodes that share not connections to other nodes, but property values.  These property values exist only for a few node types at the moment, specifically chemicals and diseases.  But we anticipate that the property landscape will increase over time.

# %%
#Those that have been coalesced via a shared property (property coalescence)
property_coalesced_results = list(
    filter( lambda x: x['node_bindings']['n1'][0]['coalescence_method'] == 'property_enrichment', coalesced_results)
)
print(len(property_coalesced_results))
# Out:
# 50

# %% [markdown]
# Here is the structure of a property coalesced result.  The p_values and properties are in the node bindings of the result.

# %%
printjson(property_coalesced_results[0])
# Out:
# {
#     "node_bindings": {
#         "n0": [
#             {
#                 "id": "NCBIGene:6611"
#             }
#         ],
#         "n1": [
#             {
#                 "id": "PUBCHEM.COMPOUND:60838",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:36462",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5284550",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4178",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:119828",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:65057",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:107867",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:3335",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:4075",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5311281",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:5330286",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:68911",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             },
#             {
#                 "id": "PUBCHEM.COMPOUND:11977753",
#                 "properties": [
#                     "drug",
#                     "pharmaceutical",
#                     "application"
#                 ],
#                 "coalescence_method": "property_enrichment",
#                 "p_values": [
#                     2.0204155691683598e-15,
#                     2.421493278176092e-15,
#                     3.0888730542428343e-13
#                 ]
#             }
#         ]
#     },
#     "edge_bindings": {
#         "e01": [
#             {
#                 "id": "09d94868f616",
#                 "weight": 1
#             },
#             {
#                 "id": "8c92bddf620d",
#                 "weight": 1
#             },
#             {
#                 "id": "e1b17345df8b",
#                 "weight": 1
#             },
#             {
#                 "id": "e6bc3a4d1c53",
#                 "weight": 1
#             },
#             {
#                 "id": "6dd4086c9e7a",
#                 "weight": 1
#             },
#             {
#                 "id": "9ef01671dfec",
#                 "weight": 1
#             },
#             {
#                 "id": "d67d490a5eab",
#                 "weight": 1
#             },
#             {
#                 "id": "8a23065bea55",
#                 "weight": 1
#             },
#             {
#                 "id": "544c025e519f",
#                 "weight": 1
#             },
#             {
#                 "id": "8ee217e1b930",
#                 "weight": 1
#             },
#             {
#                 "id": "f00b8f979a52",
#                 "weight": 1
#             },
#             {
#                 "id": "5c12b356a2cd",
#                 "weight": 1
#             },
#             {
#                 "id": "e29597429265",
#                 "weight": 1
#             }
#         ]
#     },
#     "score": 0
# }

# %% [markdown]
# This function prints out the combined nodes, as well as the properties that they share, and the p-value of the enrichment.

# %%
def print_pc_result(pc_result):
    print('p_value:', pc_result['node_bindings']['n1'][0]['p_values'])
    print('properties:', pc_result['node_bindings']['n1'][0]['properties'])
    for node in pc_result['node_bindings']['n1']:
        kgn = aragorn_result['message']['knowledge_graph']['nodes'][node['id']]
        print( f"  {kgn['name']}")
print_pc_result(property_coalesced_results[0])
# Out:
# p_value: [2.0204155691683598e-15, 2.421493278176092e-15, 3.0888730542428343e-13]
# properties: ['drug', 'pharmaceutical', 'application']
#   Irinotecan
#   Etoposide
#   Dosulepin
#   Mexiletine
#   Parecoxib
#   Diphenylcyclopropenone
#   Otenzepad
#   Fenbufen
#   Mesalamine
#   Cytochalasin B
#   Palbociclib
#   Artemether
#   Dactolisib

# %% [markdown]
# Now, these are the full set of results for property enrichments:

# %%
for pc_result in property_coalesced_results:
    print_pc_result(pc_result)
# Out:
# p_value: [2.0204155691683598e-15, 2.421493278176092e-15, 3.0888730542428343e-13]
# properties: ['drug', 'pharmaceutical', 'application']
#   Irinotecan
#   Etoposide
#   Dosulepin
#   Mexiletine
#   Parecoxib
#   Diphenylcyclopropenone
#   Otenzepad
#   Fenbufen
#   Mesalamine
#   Cytochalasin B
#   Palbociclib
#   Artemether
#   Dactolisib
# p_value: [5.767032680186795e-15]
# properties: ['drugbank.approved']
#   Irinotecan
#   Etoposide
#   Dosulepin
#   Mexiletine
#   Trimebutine
#   Parecoxib
#   Fenbufen
#   Mesalamine
#   Palbociclib
#   Artemether
# p_value: [2.6996958599386434e-14]
# properties: ['Cytochrome P-450 Substrates']
#   Irinotecan
#   Artemether
#   Etoposide
#   Dosulepin
#   Mexiletine
#   Palbociclib
#   Trimebutine
#   Parecoxib
# p_value: [8.794931414496024e-14]
# properties: ['therapeutic_flag']
#   Irinotecan
#   Etoposide
#   Dosulepin
#   Mexiletine
#   Parecoxib
#   Fenbufen
#   Mesalamine
#   Palbociclib
#   Artemether
#   Dactolisib
# p_value: [3.5279060649873544e-13, 4.597521834623776e-13]
# properties: ['Cytochrome P-450 CYP3A4 Substrates', 'Cytochrome P-450 CYP3A Substrates']
#   Irinotecan
#   Artemether
#   Etoposide
#   Mexiletine
#   Palbociclib
#   Trimebutine
#   Parecoxib
# p_value: [1.100283627624402e-11]
# properties: ['Enzyme Inhibitors']
#   Irinotecan
#   Fenbufen
#   Etoposide
#   Mocetinostat
#   Palbociclib
#   Parecoxib
# p_value: [1.3078425540231335e-10]
# properties: ['drugbank.investigational']
#   Irinotecan
#   Mocetinostat
#   Mexiletine
#   Palbociclib
#   Procysteine
#   Diphenylcyclopropenone
#   Dactolisib
# p_value: [1.4154182085640105e-10]
# properties: ['Antineoplastic Agents']
#   Irinotecan
#   Etoposide
#   Mocetinostat
#   Palbociclib
#   Dactolisib
# p_value: [1.5520642610327253e-10]
# properties: ['Cytochrome P-450 CYP2B6 Substrates']
#   Mexiletine
#   Irinotecan
#   Artemether
#   Dosulepin
# p_value: [1.9385382029440696e-10]
# properties: ['Agents that produce hypertension']
#   Fenbufen
#   Mesalamine
#   Dosulepin
#   Parecoxib
#   Taxifolin
# p_value: [3.374998412311457e-10, 1.0397813641535824e-09, 4.307534816364724e-09, 6.600752821056972e-09]
# properties: ['Anti-Inflammatory Agents, Non-Steroidal', 'Analgesics, Non-Narcotic', 'Anti-Inflammatory Agents', 'Analgesics']
#   Parecoxib
#   Fenbufen
#   Mesalamine
#   Taxifolin
# p_value: [3.962411261390769e-10]
# properties: ['Benzene Derivatives']
#   Mesalamine
#   Etoposide
#   Mocetinostat
#   Mexiletine
#   Trimebutine
# p_value: [1.9022171441463873e-09]
# properties: ['Cytochrome P-450 Enzyme Inhibitors']
#   Etoposide
#   Dosulepin
#   Mexiletine
#   Palbociclib
#   Parecoxib
# p_value: [1.2430051859117852e-08]
# properties: ['Agents causing hyperkalemia']
#   Trimebutine
#   Parecoxib
#   Fenbufen
#   Mesalamine
# p_value: [3.346199175725068e-08]
# properties: ['QTc Prolonging Agents']
#   Trimebutine
#   Artemether
#   Mocetinostat
#   Dosulepin
# p_value: [5.902924622585473e-08, 8.154540577951359e-08, 7.901575804217964e-07, 9.364782318603469e-07, 2.227115048532635e-06]
# properties: ['BCRP/ABCG2 Substrates', 'Myelosuppressive Agents', 'Immunosuppressive Agents', 'Antineoplastic and Immunomodulating Agents', 'P-glycoprotein substrates']
#   Irinotecan
#   Palbociclib
#   Etoposide
# p_value: [5.902924622585473e-08]
# properties: ['Non COX-2 selective NSAIDS']
#   Fenbufen
#   Mesalamine
#   Taxifolin
# p_value: [9.144764196664172e-08]
# properties: ['Peripheral Nervous System Agents']
#   Trimebutine
#   Parecoxib
#   Fenbufen
#   Taxifolin
# p_value: [2.0837509964980575e-07]
# properties: ['oral']
#   Mesalamine
#   Etoposide
#   Mexiletine
#   Palbociclib
#   Artemether
# p_value: [2.8073596892613677e-07, 1.5192349433851592e-06]
# properties: ['Antirheumatic Agents', 'Sensory System Agents']
#   Parecoxib
#   Fenbufen
#   Taxifolin
# p_value: [3.7871619780582746e-07]
# properties: ['Phenols']
#   Mexiletine
#   Trimebutine
#   Mesalamine
# p_value: [3.8356335768635183e-07]
# properties: ['Central Nervous System Agents']
#   Parecoxib
#   Fenbufen
#   Taxifolin
#   Dosulepin
# p_value: [5.545807815094373e-07, 9.364782318603469e-07, 9.93840773714402e-07, 1.5583263742428206e-06, 2.8507964348258742e-05]
# properties: ['non_steroidal_anti_inflammatory_drug', 'Nephrotoxic agents', 'antirheumatic_drug', 'anti_inflammatory_drug', 'anti_inflammatory_agent']
#   Parecoxib
#   Fenbufen
#   Mesalamine
# p_value: [5.952429442484947e-07]
# properties: ['Cytochrome P-450 CYP3A5 Substrates']
#   Irinotecan
#   Artemether
#   Etoposide
# p_value: [9.930783109563262e-07, 5.115535139223641e-05]
# properties: ['Cytochrome P-450 CYP1A2 Inhibitors (moderate)', 'Cytochrome P-450 CYP1A2 Inhibitors']
#   Mexiletine
#   Dosulepin
# p_value: [1.4807995610834466e-06]
# properties: ['Acids, Carbocyclic']
#   Trimebutine
#   Fenbufen
#   Mocetinostat
# p_value: [2.427708184412765e-06, 3.825414334518272e-06]
# properties: ['enzyme_inhibitor', 'inhibitor']
#   Irinotecan
#   Etoposide
#   Palbociclib
#   Parecoxib
#   Dactolisib
# p_value: [3.596981422942446e-06, 9.713523740169382e-06, 7.324055068750535e-05]
# properties: ['Phenyl Ethers', 'Ethers', 'Antiarrhythmic agents']
#   Mexiletine
#   Trimebutine
# p_value: [7.461199221817438e-06]
# properties: ['Hydroxybenzoates']
#   Trimebutine
#   Mesalamine
# p_value: [7.816040268435716e-06, 1.7164418975940646e-05, 2.1676506449781737e-05, 7.655595404310156e-05]
# properties: ['Cyclooxygenase Inhibitors', 'Antiinflammatory and Antirheumatic Products, Non-Steroids', 'Antiinflammatory and Antirheumatic Products', 'Musculo-Skeletal System']
#   Parecoxib
#   Fenbufen
# p_value: [8.550382326218318e-06, 1.935498581337847e-05]
# properties: ['Topoisomerase Inhibitors', 'UGT1A1 Substrates']
#   Irinotecan
#   Etoposide
# p_value: [1.461050391768555e-05]
# properties: ['Cytochrome P-450 CYP2E1 Substrates']
#   Mexiletine
#   Etoposide
# p_value: [1.5185941994655305e-05]
# properties: ['antineoplastic_agent']
#   Irinotecan
#   Palbociclib
#   Etoposide
#   Dactolisib
# p_value: [3.0873215823287424e-05]
# properties: ['biological_role']
#   Irinotecan
#   Etoposide
#   Ricinine
#   Parecoxib
#   Diphenylcyclopropenone
#   Taxifolin
#   Otenzepad
#   Cytochalasin B
#   Palbociclib
#   Artemether
#   Dactolisib
# p_value: [4.409835972122219e-05, 8.340508982764647e-05]
# properties: ['Cytochrome P-450 CYP2C9 Inhibitors (strength unknown)', 'Cytochrome P-450 CYP2C9 Inhibitors']
#   Parecoxib
#   Dosulepin
# p_value: [5.115535139223641e-05, 9.298965150155301e-05]
# properties: ['Muscarinic Antagonists', 'Anticholinergic Agents']
#   Trimebutine
#   Dosulepin
# p_value: [8.693874563940759e-05]
# properties: ['Benzoates']
#   Trimebutine
#   Mocetinostat
# p_value: [3.2673824848022056e-05]
# properties: ['drugbank.experimental']
#   Spermine
#   5'-Deoxy-5'-methylthioadenosine
# p_value: [5.662525412287588e-14, 3.85007304983662e-12, 1.3021304287631644e-11, 8.032033897953942e-11, 4.279428922048598e-08, 6.914569521324714e-08]
# properties: ['Biogenic Polyamines', 'Diamines', 'Polyamines', 'Biogenic Amines', 'fundamental_metabolite', 'Amines']
#   Spermine
#   1,4-Diaminobutane
#   Spermidine
# p_value: [9.975438156345684e-09, 1.9746460328580215e-08, 7.739666252503833e-08]
# properties: ['metabolite', 'biochemical_role', 'biological_role']
#   Spermine
#   1,4-Diaminobutane
#   S-Adenosylmethioninamine
#   5'-Deoxy-5'-methylthioadenosine
#   1,3-Diaminopropane
#   N1-Acetylspermine
#   Spermidine
# p_value: [7.324458236964524e-08]
# properties: ['drugbank.experimental']
#   Spermine
#   5'-Deoxy-5'-methylthioadenosine
#   1,4-Diaminobutane
#   Spermidine
# p_value: [1.2436395129274456e-07, 1.2495403577505464e-07, 1.2546159449526366e-07, 6.995229458695576e-06]
# properties: ['Bronsted_base', 'base', 'acceptor', 'chemical_role']
#   Spermine
#   1,4-Diaminobutane
#   1,3-Diaminopropane
#   Bis(3-aminopropyl)amine
#   Spermidine
# p_value: [1.9429826482967636e-07]
# properties: ['OCT1 substrates']
#   Spermine
#   Spermidine
# p_value: [6.02427022862859e-06, 8.25637389853852e-06, 5.487439301399221e-05]
# properties: ['mammalian_metabolite', 'animal_metabolite', 'eukaryotic_metabolite']
#   5'-Deoxy-5'-methylthioadenosine
#   1,3-Diaminopropane
#   S-Adenosylmethioninamine
#   N1-Acetylspermine
# p_value: [2.2109740054334953e-05]
# properties: ['mouse_metabolite']
#   5'-Deoxy-5'-methylthioadenosine
#   1,3-Diaminopropane
#   S-Adenosylmethioninamine
# p_value: [4.496031823204172e-05]
# properties: ['antioxidant']
#   Spermine
#   1,4-Diaminobutane
# p_value: [8.720200599146962e-05]
# properties: ['human_metabolite']
#   5'-Deoxy-5'-methylthioadenosine
#   1,3-Diaminopropane
#   N1-Acetylspermine
# p_value: [1.011176916899218e-14, 6.875685711130518e-13, 2.3255280271103596e-12, 1.4346393259377525e-11, 7.657506321149441e-09, 1.2377191018442222e-08, 1.8504712585934775e-06, 6.428138698108782e-05, 6.446419353254804e-05, 6.462115767208196e-05]
# properties: ['Biogenic Polyamines', 'Diamines', 'Polyamines', 'Biogenic Amines', 'fundamental_metabolite', 'Amines', 'drugbank.experimental', 'Bronsted_base', 'base', 'acceptor']
#   1,4-Diaminobutane
#   Spermine
#   Spermidine
# p_value: [6.9403268836742e-08]
# properties: ['OCT1 substrates']
#   Spermine
#   Spermidine
# p_value: [1.6097982876445663e-05]
# properties: ['antioxidant']
#   1,4-Diaminobutane
#   Spermine

# %% [markdown]
# Consistent with the graph coalescence we see properties indicating P450 substrates, and antineoplastic drugs.
