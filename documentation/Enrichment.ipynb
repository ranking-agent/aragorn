# %% [markdown]
# # Setup

# %%
import json
import requests
import copy
from datetime import datetime as dt
from collections import defaultdict
import pandas as pd

# %%
#https://pypi.org/project/gamma-viewer/
from gamma_viewer import GammaViewer
from IPython.display import display, Markdown

# %%
def printjson(j):
    print(json.dumps(j,indent=4))
def print_json(j):
    printjson(j)

# %%
def post(name,url,message,params=None):
    """A simple function for posting to a URL and returning the json response"""
    if params is None:
        response = requests.post(url,json=message)
    else:
        response = requests.post(url,json=message,params=params)
    if not response.status_code == 200:
        print(name, 'error:',response.status_code)
        print(response)
        print(response.json())
        return {}
    return response.json()

# %%
def coalesce(em):
    return post('coalesce','https://answercoalesce.renci.org/coalesce/all',em)

# %%
def normalize(ids):
    j = {'curies':ids}
    result = post('nn','https://nodenormalization-sri.renci.org/get_normalized_nodes',j)
    new_ids = [ v['id']['identifier'] for k,v in result.items() ]
    return new_ids

# %%
def enrich(biolink_category, identifiers):
    identifiers = normalize(identifiers)
    em={'message': 
         {
             'query_graph':
                  {
                    "nodes": {
                        "n1": {
                            "category": [ biolink_category ]
                            }
                    },
                    "edges":{}  
                  },
              'knowledge_graph': {
                  'nodes': {},
                  'edges': {}
                  },
              'results': []
        }
    }
    for n in identifiers:
        em['message']['knowledge_graph']['nodes'][n]= {'category':[biolink_category]}
        em['message']['results'].append( {'node_bindings': {'n1':[{"id": n}]}, 'edge_bindings': {} })
    return coalesce(em)

# %%
def ac_to_table(aragorn_result,mnode):
    #scores = []
    answer_node_count = []
    merged_count = []
    method = []
    extra = []
    for res_i, result in enumerate(aragorn_result['message']['results']):
        #scores.append(result['score'])
        answer_node_count.append(len(result['node_bindings']))
        merged_count.append(len(result['node_bindings'][mnode]))
        try:
            method.append(result['node_bindings'][mnode][0]['coalescence_method'])
        except:
            method.append('Original')
    df = pd.DataFrame({'N_Answer_Nodes':answer_node_count, 'N_Merged_Nodes':merged_count, 'Method':method})
    return df

def filter_to_simple(aragorn_result,mnode):
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = list(
    filter( lambda x: 'coalescence_method' not in x['node_bindings'][mnode][0], 
           aragorn_result['message']['results'])
    )
    print(len(simple_result['message']['results']))
    return simple_result

def print_nodenames(simple_result,qnode):
    #Print the names of the answers
    for result in simple_result['message']['results']:
        #Each answer has an identifier:
        n1_id = result['node_bindings'][qnode][0]['id']
        #The information for that identifier is in the KG:
        node = simple_result['message']['knowledge_graph']['nodes'][n1_id]
        #Each node has a name
        print(node['name'])

def filter_to_coal(aragorn_result,mnode,method):
    #The results that have been coalesced:
    coalesced_results = list(
        filter( lambda x: 'coalescence_method'  in x['node_bindings'][mnode][0], 
               aragorn_result['message']['results'])
    )
    #Those that have been coalesced via a new node (graph coalescence)
    graph_coalesced_results = list(
        filter( lambda x: x['node_bindings'][mnode][0]['coalescence_method'] == method, coalesced_results)
    )
    print(len(graph_coalesced_results))
    simple_result = copy.deepcopy(aragorn_result)
    simple_result['message']['results'] = graph_coalesced_results
    return simple_result

def filter_to_gc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'graph_enrichment')

def filter_to_pc(aragorn_result,mnode):
    return filter_to_coal(aragorn_result,mnode,'property_enrichment')

# %%
def print_gc_result(graph,gc_result):
    print('p_value:', gc_result['node_bindings']['n1'][0]['p_value'])
    for eb in gc_result['edge_bindings']['extra_qe_0']:
        kge = graph['edges'][eb['id']]
        subject_node = kge['subject']
        object_node = kge['object']
        pred = kge['predicate']
        print( f"{graph['nodes'][subject_node]['name']} -[{pred}]-> {graph['nodes'][object_node]['name']}")

# %% [markdown]
# Here's the actual thing:

# %%
answer = enrich('biolink:Gene',['NCBIGene:191',
 'NCBIGene:55832',
 'NCBIGene:645',
 'NCBIGene:54884',
 'NCBIGene:8239',
 'NCBIGene:4175',
 'NCBIGene:10469',
 'NCBIGene:8120',
 'NCBIGene:3840',
 'NCBIGene:55705',
 'NCBIGene:2597',
 'NCBIGene:23066',
 'NCBIGene:7514',
 'NCBIGene:10128'])

# %%
ac_to_table(answer,'n1')
# Out:
#     N_Answer_Nodes  N_Merged_Nodes            Method
# 0                2              13  graph_enrichment
# 1                2              12  graph_enrichment
# 2                2               8  graph_enrichment
# 3                2              12  graph_enrichment
# 4                2              13  graph_enrichment
# 5                2              11  graph_enrichment
# 6                2              13  graph_enrichment
# 7                2              10  graph_enrichment
# 8                2              13  graph_enrichment
# 9                2              13  graph_enrichment
# 10               2              12  graph_enrichment
# 11               2              12  graph_enrichment
# 12               2              13  graph_enrichment
# 13               2              13  graph_enrichment
# 14               2              10  graph_enrichment
# 15               1               1          Original
# 16               1               1          Original
# 17               1               1          Original
# 18               1               1          Original
# 19               1               1          Original
# 20               1               1          Original
# 21               1               1          Original
# 22               1               1          Original
# 23               1               1          Original
# 24               1               1          Original
# 25               1               1          Original
# 26               1               1          Original
# 27               1               1          Original
# 28               1               1          Original

# %%
x = filter_to_gc(answer,'n1')
# Out:
# 15

# %%
for i,result in enumerate(x['message']['results']):
    print('Result',i)
    print_gc_result(x['message']['knowledge_graph'],result)
# Out:
# Result 0
# p_value: 1.9150723523368846e-15
# blood -[biolink:expresses]-> TIMM44
# blood -[biolink:expresses]-> RETSAT
# blood -[biolink:expresses]-> LRPPRC
# blood -[biolink:expresses]-> GAPDH
# blood -[biolink:expresses]-> BLVRB
# blood -[biolink:expresses]-> XPO1
# blood -[biolink:expresses]-> MCM6
# blood -[biolink:expresses]-> USP9X
# blood -[biolink:expresses]-> AP3B2
# blood -[biolink:expresses]-> CAND2
# blood -[biolink:expresses]-> AHCY
# blood -[biolink:expresses]-> IPO9
# blood -[biolink:expresses]-> KPNA4
# Result 1
# p_value: 2.3920933258387157e-15
# medulla oblongata -[biolink:expresses]-> GAPDH
# medulla oblongata -[biolink:expresses]-> KPNA4
# medulla oblongata -[biolink:expresses]-> USP9X
# medulla oblongata -[biolink:expresses]-> RETSAT
# medulla oblongata -[biolink:expresses]-> TIMM44
# medulla oblongata -[biolink:expresses]-> LRPPRC
# medulla oblongata -[biolink:expresses]-> CAND2
# medulla oblongata -[biolink:expresses]-> BLVRB
# medulla oblongata -[biolink:expresses]-> MCM6
# medulla oblongata -[biolink:expresses]-> AHCY
# medulla oblongata -[biolink:expresses]-> AP3B2
# medulla oblongata -[biolink:expresses]-> XPO1
# Result 2
# p_value: 2.8956492328789973e-15
# JUN -[biolink:molecularly_interacts_with]-> USP9X
# JUN -[biolink:molecularly_interacts_with]-> GAPDH
# JUN -[biolink:molecularly_interacts_with]-> IPO9
# JUN -[biolink:molecularly_interacts_with]-> LRPPRC
# JUN -[biolink:molecularly_interacts_with]-> XPO1
# JUN -[biolink:molecularly_interacts_with]-> AHCY
# JUN -[biolink:molecularly_interacts_with]-> CAND1
# JUN -[biolink:molecularly_interacts_with]-> KPNA4
# Result 3
# p_value: 2.9658040631003975e-15
# spinal cord -[biolink:expresses]-> GAPDH
# spinal cord -[biolink:expresses]-> USP9X
# spinal cord -[biolink:expresses]-> BLVRB
# spinal cord -[biolink:expresses]-> LRPPRC
# spinal cord -[biolink:expresses]-> IPO9
# spinal cord -[biolink:expresses]-> XPO1
# spinal cord -[biolink:expresses]-> AHCY
# spinal cord -[biolink:expresses]-> AP3B2
# spinal cord -[biolink:expresses]-> KPNA4
# spinal cord -[biolink:expresses]-> CAND2
# spinal cord -[biolink:expresses]-> RETSAT
# spinal cord -[biolink:expresses]-> TIMM44
# Result 4
# p_value: 2.9833460572884683e-15
# vagina -[biolink:expresses]-> BLVRB
# vagina -[biolink:expresses]-> XPO1
# vagina -[biolink:expresses]-> AP3B2
# vagina -[biolink:expresses]-> RETSAT
# vagina -[biolink:expresses]-> TIMM44
# vagina -[biolink:expresses]-> AHCY
# vagina -[biolink:expresses]-> KPNA4
# vagina -[biolink:expresses]-> USP9X
# vagina -[biolink:expresses]-> IPO9
# vagina -[biolink:expresses]-> LRPPRC
# vagina -[biolink:expresses]-> GAPDH
# vagina -[biolink:expresses]-> CAND2
# vagina -[biolink:expresses]-> MCM6
# Result 5
# p_value: 5.485466227989627e-15
# myocardium -[biolink:expresses]-> RETSAT
# myocardium -[biolink:expresses]-> KPNA4
# myocardium -[biolink:expresses]-> TIMM44
# myocardium -[biolink:expresses]-> BLVRB
# myocardium -[biolink:expresses]-> AHCY
# myocardium -[biolink:expresses]-> XPO1
# myocardium -[biolink:expresses]-> CAND2
# myocardium -[biolink:expresses]-> MCM6
# myocardium -[biolink:expresses]-> GAPDH
# myocardium -[biolink:expresses]-> USP9X
# myocardium -[biolink:expresses]-> LRPPRC
# Result 6
# p_value: 7.0496526095770025e-15
# liver -[biolink:expresses]-> IPO9
# liver -[biolink:expresses]-> USP9X
# liver -[biolink:expresses]-> BLVRB
# liver -[biolink:expresses]-> CAND2
# liver -[biolink:expresses]-> MCM6
# liver -[biolink:expresses]-> AHCY
# liver -[biolink:expresses]-> LRPPRC
# liver -[biolink:expresses]-> XPO1
# liver -[biolink:expresses]-> RETSAT
# liver -[biolink:expresses]-> AP3B2
# liver -[biolink:expresses]-> GAPDH
# liver -[biolink:expresses]-> KPNA4
# liver -[biolink:expresses]-> TIMM44
# Result 7
# p_value: 8.277569468571573e-15
# cardiovascular system -[biolink:expresses]-> USP9X
# cardiovascular system -[biolink:expresses]-> XPO1
# cardiovascular system -[biolink:expresses]-> KPNA4
# cardiovascular system -[biolink:expresses]-> CAND2
# cardiovascular system -[biolink:expresses]-> TIMM44
# cardiovascular system -[biolink:expresses]-> MCM6
# cardiovascular system -[biolink:expresses]-> AHCY
# cardiovascular system -[biolink:expresses]-> GAPDH
# cardiovascular system -[biolink:expresses]-> LRPPRC
# cardiovascular system -[biolink:expresses]-> BLVRB
# Result 8
# p_value: 1.0170236650055939e-14
# adipose tissue -[biolink:expresses]-> IPO9
# adipose tissue -[biolink:expresses]-> MCM6
# adipose tissue -[biolink:expresses]-> KPNA4
# adipose tissue -[biolink:expresses]-> USP9X
# adipose tissue -[biolink:expresses]-> GAPDH
# adipose tissue -[biolink:expresses]-> TIMM44
# adipose tissue -[biolink:expresses]-> LRPPRC
# adipose tissue -[biolink:expresses]-> RETSAT
# adipose tissue -[biolink:expresses]-> AP3B2
# adipose tissue -[biolink:expresses]-> XPO1
# adipose tissue -[biolink:expresses]-> CAND2
# adipose tissue -[biolink:expresses]-> AHCY
# adipose tissue -[biolink:expresses]-> BLVRB
# Result 9
# p_value: 1.7318634581465444e-14
# thyroid gland -[biolink:expresses]-> KPNA4
# thyroid gland -[biolink:expresses]-> AP3B2
# thyroid gland -[biolink:expresses]-> AHCY
# thyroid gland -[biolink:expresses]-> GAPDH
# thyroid gland -[biolink:expresses]-> RETSAT
# thyroid gland -[biolink:expresses]-> BLVRB
# thyroid gland -[biolink:expresses]-> LRPPRC
# thyroid gland -[biolink:expresses]-> IPO9
# thyroid gland -[biolink:expresses]-> MCM6
# thyroid gland -[biolink:expresses]-> CAND2
# thyroid gland -[biolink:expresses]-> TIMM44
# thyroid gland -[biolink:expresses]-> XPO1
# thyroid gland -[biolink:expresses]-> USP9X
# Result 10
# p_value: 1.808695311812454e-14
# pituitary gland -[biolink:expresses]-> AP3B2
# pituitary gland -[biolink:expresses]-> CAND2
# pituitary gland -[biolink:expresses]-> XPO1
# pituitary gland -[biolink:expresses]-> TIMM44
# pituitary gland -[biolink:expresses]-> KPNA4
# pituitary gland -[biolink:expresses]-> RETSAT
# pituitary gland -[biolink:expresses]-> LRPPRC
# pituitary gland -[biolink:expresses]-> BLVRB
# pituitary gland -[biolink:expresses]-> GAPDH
# pituitary gland -[biolink:expresses]-> IPO9
# pituitary gland -[biolink:expresses]-> AHCY
# pituitary gland -[biolink:expresses]-> USP9X
# Result 11
# p_value: 2.354133972702182e-14
# tendon -[biolink:expresses]-> RETSAT
# tendon -[biolink:expresses]-> LRPPRC
# tendon -[biolink:expresses]-> KPNA4
# tendon -[biolink:expresses]-> CAND2
# tendon -[biolink:expresses]-> XPO1
# tendon -[biolink:expresses]-> USP9X
# tendon -[biolink:expresses]-> BLVRB
# tendon -[biolink:expresses]-> AHCY
# tendon -[biolink:expresses]-> GAPDH
# tendon -[biolink:expresses]-> MCM6
# tendon -[biolink:expresses]-> IPO9
# tendon -[biolink:expresses]-> TIMM44
# Result 12
# p_value: 2.6305395107392466e-14
# telencephalon -[biolink:expresses]-> AHCY
# telencephalon -[biolink:expresses]-> XPO1
# telencephalon -[biolink:expresses]-> KPNA4
# telencephalon -[biolink:expresses]-> USP9X
# telencephalon -[biolink:expresses]-> GAPDH
# telencephalon -[biolink:expresses]-> CAND2
# telencephalon -[biolink:expresses]-> AP3B2
# telencephalon -[biolink:expresses]-> IPO9
# telencephalon -[biolink:expresses]-> TIMM44
# telencephalon -[biolink:expresses]-> MCM6
# telencephalon -[biolink:expresses]-> BLVRB
# telencephalon -[biolink:expresses]-> RETSAT
# telencephalon -[biolink:expresses]-> LRPPRC
# Result 13
# p_value: 2.8950403816187655e-14
# prostate gland -[biolink:expresses]-> MCM6
# prostate gland -[biolink:expresses]-> AHCY
# prostate gland -[biolink:expresses]-> TIMM44
# prostate gland -[biolink:expresses]-> GAPDH
# prostate gland -[biolink:expresses]-> LRPPRC
# prostate gland -[biolink:expresses]-> KPNA4
# prostate gland -[biolink:expresses]-> CAND2
# prostate gland -[biolink:expresses]-> IPO9
# prostate gland -[biolink:expresses]-> AP3B2
# prostate gland -[biolink:expresses]-> USP9X
# prostate gland -[biolink:expresses]-> BLVRB
# prostate gland -[biolink:expresses]-> RETSAT
# prostate gland -[biolink:expresses]-> XPO1
# Result 14
# p_value: 5.3352483919928556e-14
# cardiac ventricle -[biolink:expresses]-> TIMM44
# cardiac ventricle -[biolink:expresses]-> GAPDH
# cardiac ventricle -[biolink:expresses]-> LRPPRC
# cardiac ventricle -[biolink:expresses]-> RETSAT
# cardiac ventricle -[biolink:expresses]-> BLVRB
# cardiac ventricle -[biolink:expresses]-> CAND2
# cardiac ventricle -[biolink:expresses]-> AHCY
# cardiac ventricle -[biolink:expresses]-> USP9X
# cardiac ventricle -[biolink:expresses]-> KPNA4
# cardiac ventricle -[biolink:expresses]-> XPO1
